# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import svm
from sklearn.svm import LinearSVC
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, plot_confusion_matrix
import nltk

import pickle

pd.options.display.float_format = '{:.0f}'.format

# %%
#Load in data and split for train and test sets
df = pd.read_csv(r'C:\Users\jackc\Semester2\Project\Identifying-Hate-Speech-Categories-On-Social-Media\Data\clean_dataset.csv')
X_train, X_test, y_train, y_test = train_test_split(df['clean_text_sl'], df['Hate'], test_size=0.25, random_state=12)
                                                       
df.head(5)
# Out:
#                   id                                               text  \
# 0 596965466238619648  I just found the *perfect* rental. Why can't m...
# 1 575891807873040384  @wetsprocket every time they "discover" anythi...
# 2 595259457828884480  ok time to write code bbl.\n\nmaking a new thing.
# 3 572344911002927104                          Refined dessert! NOT #MKR
# 4 568132033215475712  @furt1v3ly @ClarkHat One of the best things an...
#
#   Annotation                                         clean_text  \
# 0    Neither  i just found the perfect rental why cant my le...
# 1    Neither   every time they discover anything its either ...
# 2    Neither    ok time to write code bbl\n\nmaking a new thing
# 3    Neither                            refined dessert not mkr
# 4    Neither    one of the best things anyone can do to impr...
#
#                                        clean_text_sl  Hate
# 0              found perfect rental cant lease right     0
# 1  every time discover anything either incorrect ...     0
# 2            ok time write code bbl making new thing     0
# 3                                refined dessert mkr     0
# 4  one best thing anyone improve understanding gr...     0

# %%
#create count matrix
counts = CountVectorizer()
count_train = counts.fit_transform(X_train)
count_test = counts.transform(X_test)

# %% [markdown]
# ## Default SVM

# %%
SVM_default = svm.SVC(C=1.0, kernel='rbf', gamma='scale', shrinking=True,
                      class_weight=None, random_state=12)

# %%
# train classifier
print("training...")
SVM_default.fit(count_train, y_train)
print("complete.")
# use classifier to predict on test set
print("predicting...")
SVM_test_preds = SVM_default.predict(count_test)
print("complete.")
# Out:
# training...
# complete.
# predicting...
# complete.

# %%
SVM_metrics = {}
SVM_default_precision = precision_score(y_test, SVM_test_preds)
SVM_default_recall = recall_score(y_test, SVM_test_preds)
SVM_default_macro_f1_score = f1_score(y_test, SVM_test_preds, average='macro')

#model evaluation
print('Model evaluation metrics')
print('Precision: {:.3}'.format(SVM_default_precision))
print('Recall: {:.3}'.format(SVM_default_recall))
print('Macro F1 Score: {:.3}'.format(SVM_default_macro_f1_score))

SVM_metrics['Default SVM'] = {'precision': SVM_default_precision, 'recall': SVM_default_recall, 
                              'macro_f1': SVM_default_macro_f1_score}
# Out:
# Model evaluation metrics
# Precision: 0.776
# Recall: 0.538
# Macro F1 Score: 0.789

# %%
plot_confusion_matrix(SVM_default, count_test, y_test)

# %% [markdown]
# ## Grid Search SVM

# %%
SVM_default_grid = svm.SVC(C=1.0, kernel='rbf', gamma='scale', shrinking=True,
                      class_weight=None, random_state=12)

# dictionary containing the parameters which will be used for grid search
grid_search_params={'C': [1, 10, 30],  
              'gamma': ['auto', 0.1, 0.01], 
              'kernel': ['rbf', 'sigmoid', 'linear', 'poly'],
              'coef0': [0.1, 1, 3],
              'degree': [1, 3, 5],
              'class_weight': [None, 'balanced']}

# grid search with f1 being the performance metric
SVM_grid = GridSearchCV(SVM_default_grid, grid_search_params, cv=5, scoring='f1_macro', verbose=3)
SVM_grid.fit(count_train, y_train)
# Out:
# Fitting 5 folds for each of 648 candidates, totalling 3240 fits
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.457, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.1s remaining:    0.0s
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.456, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.457, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.836, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.808, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.797, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.827, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.790, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.457, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.827, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.808, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.790, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.803, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.783, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.844, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.814, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.802, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.818, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.786, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.836, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.808, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.797, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.827, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.790, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.848, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.830, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.809, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.825, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.793, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.801, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.764, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.745, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.764, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.743, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.801, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.764, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.745, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.764, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.743, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.836, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.808, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.797, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.827, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.790, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.801, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.764, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.745, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.764, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.743, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.457, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.456, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.457, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.836, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.808, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.797, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.827, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.790, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.457, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.827, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.808, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.790, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.803, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.783, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.844, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.814, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.802, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.818, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.786, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.836, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.808, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.797, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.827, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.790, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.751, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.781, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.748, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.782, total=   1.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.750, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.801, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.764, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.745, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.764, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.743, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.801, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.764, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.745, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.764, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.743, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.836, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.808, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.797, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.827, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.790, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.457, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.457, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.456, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.456, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.457, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.836, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.808, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.797, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.827, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.790, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.457, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.827, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.808, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.790, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.803, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.783, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.844, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.814, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.802, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.818, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.786, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.836, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.808, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.797, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.827, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.790, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.532, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.542, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.504, total=   1.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.531, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.511, total=   1.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.801, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.764, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.745, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.764, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.743, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.801, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.764, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.745, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.764, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.743, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.836, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.808, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.797, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.827, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.790, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.457, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.456, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.457, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.456, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.457, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.836, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.808, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.797, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.827, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.790, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.457, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.827, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.808, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.790, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.803, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.783, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.806, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.772, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.753, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.780, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.755, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.836, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.808, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.797, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.827, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.790, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.848, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.830, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.809, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.825, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.793, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.801, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.764, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.745, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.764, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.743, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.462, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.475, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.475, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.456, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.456, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.836, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.808, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.797, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.827, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.790, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.801, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.764, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.745, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.764, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.743, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.457, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.456, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.457, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.456, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.836, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.808, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.797, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.827, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.790, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.457, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.456, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.827, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.808, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.790, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.803, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.783, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid, score=0.806, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid, score=0.772, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# ...
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.828, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.798, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.834, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.774, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.841, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.848, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.806, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.844, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.811, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.801, total=   1.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.767, total=   1.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.748, total=   1.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.767, total=   1.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.746, total=   1.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.798, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.811, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.786, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.823, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.759, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.812, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.818, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.785, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.824, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.784, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.819, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.780, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.768, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.783, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.750, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.456, total=   1.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.457, total=   1.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.138, total=   1.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.138, total=   1.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.138, total=   1.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.798, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.811, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.786, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.823, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.759, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.824, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.824, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.800, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.830, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.792, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.823, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.813, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.778, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.825, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.768, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.803, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.822, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.786, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.786, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.782, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.798, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.811, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.786, total=   0.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.823, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.759, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.830, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.834, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.811, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.829, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.793, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.841, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.848, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.806, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.844, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.811, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.801, total=   1.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.767, total=   1.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.748, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.767, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.746, total=   1.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.798, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.811, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.786, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.823, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.759, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.802, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.810, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.780, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.825, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.777, total=   0.6s
# [Parallel(n_jobs=1)]: Done 3240 out of 3240 | elapsed: 47.0min finished
# GridSearchCV(cv=5, estimator=SVC(random_state=12),
#              param_grid={'C': [1, 10, 30], 'class_weight': [None, 'balanced'],
#                          'coef0': [0.1, 1, 3], 'degree': [1, 3, 5],
#                          'gamma': ['auto', 0.1, 0.01],
#                          'kernel': ['rbf', 'sigmoid', 'linear', 'poly']},
#              scoring='f1_macro', verbose=3)

# %%
#print best score obtained and the parameters which obtained it
print('Macro F1 Score:', SVM_grid.best_score_)
print('Best Hyperparameters:', SVM_grid.best_params_)
print('Model object with best parameters: ')
print(SVM_grid.best_estimator_)
# Out:
# Macro F1 Score: 0.8335817373214726
# Best Hyperparameters: {'C': 1, 'class_weight': 'balanced', 'coef0': 1, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# Model object with best parameters:
# SVC(C=1, class_weight='balanced', coef0=1, gamma=0.1, kernel='poly',
#     random_state=12)

# %%
# train classifier
print("training...")
SVM_grid.best_estimator_.fit(count_train, y_train)
print("complete.")
# use classifier to predict on test set
print("predicting...")
SVM_test_preds = SVM_grid.best_estimator_.predict(count_test)
print("complete.")
# Out:
# training...
# complete.
# predicting...
# complete.

# %%
SVM_grid_precision = precision_score(y_test, SVM_test_preds)
SVM_grid_recall = recall_score(y_test, SVM_test_preds)
SVM_grid_macro_f1_score = f1_score(y_test, SVM_test_preds, average='macro')

#model evaluation
print('Model evaluation metrics')
print('Precision: {:.3}'.format(SVM_grid_precision))
print('Recall: {:.3}'.format(SVM_grid_recall))
print('Macro F1 Score: {:.3}'.format(SVM_grid_macro_f1_score))

SVM_metrics['Grid Search SVM'] = {'precision': SVM_grid_precision, 'recall': SVM_grid_recall, 
                                  'macro_f1': SVM_grid_macro_f1_score}
# Out:
# Model evaluation metrics
# Precision: 0.749
# Recall: 0.657
# Macro F1 Score: 0.823

# %%
plot_confusion_matrix(SVM_grid.best_estimator_, count_test, y_test)

# %% [markdown]
# ## Default SVM with POS tags

# %%
#create a column of pos tagged words in each tweet
from nltk.tokenize import TweetTokenizer
tokenizer = TweetTokenizer()

tweets = df.clean_text
tweet_tags = []

for t in tweets:
    tokens = nltk.word_tokenize(t)
    tags = nltk.pos_tag(tokens)
    new_text = []
    for word in tags:
        new_text.append(word[0] + "_" + word[1])
    tweet_tags.append(new_text)
    
tagged_tokens = []
for tweet in tweet_tags:
    sent = ' '.join(tweet)
    new_tokens = tokenizer.tokenize(sent)
    tagged_tokens.append(new_tokens)
    
df['pos_tags'] = tagged_tokens
df['pos_tags'] = df['pos_tags'].apply(lambda x: ' '.join(map(str, x)))

df.head(5)
# Out:
#                   id                                               text  \
# 0 596965466238619648  I just found the *perfect* rental. Why can't m...
# 1 575891807873040384  @wetsprocket every time they "discover" anythi...
# 2 595259457828884480  ok time to write code bbl.\n\nmaking a new thing.
# 3 572344911002927104                          Refined dessert! NOT #MKR
# 4 568132033215475712  @furt1v3ly @ClarkHat One of the best things an...
#
#   Annotation                                         clean_text  \
# 0    Neither  i just found the perfect rental why cant my le...
# 1    Neither   every time they discover anything its either ...
# 2    Neither    ok time to write code bbl\n\nmaking a new thing
# 3    Neither                            refined dessert not mkr
# 4    Neither    one of the best things anyone can do to impr...
#
#                                        clean_text_sl  Hate  \
# 0              found perfect rental cant lease right     0
# 1  every time discover anything either incorrect ...     0
# 2            ok time write code bbl making new thing     0
# 3                                refined dessert mkr     0
# 4  one best thing anyone improve understanding gr...     0
#
#                                             pos_tags
# 0  i_NN just_RB found_VBD the_DT perfect_JJ renta...
# 1  every_DT time_NN they_PRP discover_VBP anythin...
# 2  ok_JJ time_NN to_TO write_VB code_NN bbl_NN ma...
# 3               refined_VBN dessert_NN not_RB mkr_VB
# 4  one_CD of_IN the_DT best_JJS things_NNS anyone...

# %%
X_train_pos, X_test_pos, y_train_pos, y_test_pos = train_test_split(df['pos_tags'], df['Hate'], test_size=0.25, random_state=12)
                                                       
count_train_pos = counts.fit_transform(X_train_pos)
count_test_pos = counts.transform(X_test_pos)

# %%
SVM_default_pos = svm.SVC(C=1.0, kernel='rbf', gamma='scale', shrinking=True,
                      class_weight=None, random_state=12)

# %%
# train classifier
print("training...")
SVM_default_pos.fit(count_train_pos, y_train_pos)
print("complete.")
# use classifier to predict on test set
print("predicting...")
SVM_test_preds_pos = SVM_default_pos.predict(count_test_pos)
print("complete.")
# Out:
# training...
# complete.
# predicting...
# complete.

# %%
SVM_pos_precision = precision_score(y_test_pos, SVM_test_preds_pos)
SVM_pos_recall = recall_score(y_test_pos, SVM_test_preds_pos)
SVM_pos_macro_f1_score = f1_score(y_test_pos, SVM_test_preds_pos, average='macro')

#model evaluation
print('Model evaluation metrics')
print('Precision: {:.3}'.format(SVM_pos_precision))
print('Recall: {:.3}'.format(SVM_pos_recall))
print('Macro F1 Score: {:.3}'.format(SVM_pos_macro_f1_score))

SVM_metrics['Default SVM with POS'] = {'precision': SVM_pos_precision, 'recall': SVM_pos_recall, 
                                       'macro_f1': SVM_pos_macro_f1_score}
# Out:
# Model evaluation metrics
# Precision: 0.804
# Recall: 0.415
# Macro F1 Score: 0.742

# %%
plot_confusion_matrix(SVM_default_pos, count_test_pos, y_test_pos)

# %% [markdown]
# ## Grid search SVM with POS tags

# %%
SVM_grid_pos = svm.SVC(C=1.0, kernel='rbf', gamma='scale', shrinking=True,
                      class_weight=None, random_state=12)

# dictionary containing the parameters which will be used for grid search
grid_search_params={'C': [1, 10, 30],  
              'gamma': ['auto', 0.1, 0.01], 
              'kernel': ['rbf', 'sigmoid', 'linear', 'poly'],
              'coef0': [0.1, 1, 3],
              'degree': [1, 3, 5],
              'class_weight': [None, 'balanced']}

# grid search with f1 being the performance metric
SVM_grid_pos = GridSearchCV(SVM_grid_pos, grid_search_params, cv=5, scoring='f1_macro', verbose=3)
SVM_grid_pos.fit(count_train_pos, y_train_pos)
# Out:
# Fitting 5 folds for each of 648 candidates, totalling 3240 fits
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.457, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.8s remaining:    0.0s
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.456, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.457, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.806, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.793, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.777, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.789, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.761, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.457, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.722, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.710, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.697, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.712, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.702, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.702, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.682, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.724, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.697, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.691, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.806, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.793, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.777, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.789, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.761, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.815, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.792, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.772, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.785, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.768, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.792, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.765, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.740, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.749, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.734, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.514, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.601, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.567, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.589, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.581, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.806, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.793, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.777, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.789, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.761, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.520, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.611, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.592, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.595, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.609, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.457, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.457, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.806, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.793, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.777, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.789, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.761, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.456, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.457, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.456, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.722, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.710, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.697, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.712, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.702, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.702, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.682, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.724, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.697, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.691, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.806, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.793, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.777, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.789, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.761, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.653, total=   2.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.658, total=   2.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.652, total=   2.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.638, total=   2.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.593, total=   2.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.792, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.765, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.740, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.749, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.734, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.514, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.601, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.567, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.589, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.581, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.806, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.793, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.777, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.789, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.761, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.456, total=   1.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.457, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.456, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.456, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.456, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.457, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.456, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.457, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.806, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.793, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.777, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.789, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.761, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.456, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.457, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.456, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.456, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.722, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.710, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.697, total=   2.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.712, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.702, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.702, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.682, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.724, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.697, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.691, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.806, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.793, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.777, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.789, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.761, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.560, total=   2.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.566, total=   2.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.563, total=   3.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.568, total=   3.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.529, total=   3.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.792, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.765, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.740, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.749, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.734, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.514, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.601, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.567, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.589, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.581, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.806, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.793, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.777, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.789, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.761, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.456, total=   1.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.457, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.456, total=   2.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.456, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.456, total=   2.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.456, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.457, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.456, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.456, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.457, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.806, total=   1.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.793, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.777, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.789, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.761, total=   1.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.457, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.722, total=   2.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.710, total=   2.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.697, total=   2.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.712, total=   2.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.702, total=   2.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.707, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.700, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.686, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.703, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.681, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.806, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.793, total=   1.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.777, total=   1.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.789, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.761, total=   1.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.815, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.792, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.772, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.785, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.768, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.792, total=   1.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.765, total=   1.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.740, total=   1.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.749, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.734, total=   1.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.456, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.457, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.456, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.456, total=   1.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.456, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.806, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.793, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.777, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.789, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.761, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.520, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.611, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.592, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.595, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.604, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.457, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.456, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.456, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.457, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.456, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.806, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.793, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.777, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.789, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.761, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.456, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.457, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.456, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.456, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.456, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.722, total=   2.3s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.710, total=   2.3s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.697, total=   2.3s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.712, total=   2.3s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.702, total=   2.4s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid, score=0.707, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid, score=0.700, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# ...
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.798, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.777, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.797, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.761, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.818, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.807, total=   1.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.797, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.786, total=   1.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.776, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.771, total=   2.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.782, total=   2.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.758, total=   2.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.737, total=   2.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.747, total=   2.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.778, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.801, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.772, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.793, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.751, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.781, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.805, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.775, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.787, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.765, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.787, total=   2.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.776, total=   2.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.746, total=   2.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.753, total=   2.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.741, total=   2.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.456, total=   3.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.457, total=   2.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.138, total=   2.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.138, total=   2.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.138, total=   3.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.778, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.801, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.772, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.793, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.751, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.797, total=   1.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.803, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.794, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.782, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.775, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.756, total=   2.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.726, total=   2.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.714, total=   2.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.743, total=   2.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.708, total=   2.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.726, total=   2.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.723, total=   1.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.706, total=   1.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.694, total=   1.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.696, total=   1.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.778, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.801, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.772, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.793, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.751, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.829, total=   2.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.786, total=   1.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.782, total=   1.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.787, total=   1.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.764, total=   1.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.818, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.807, total=   1.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.797, total=   1.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.786, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.776, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.771, total=   2.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.782, total=   2.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.758, total=   2.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.737, total=   2.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.747, total=   2.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.778, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.801, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.772, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.793, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.751, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.796, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.795, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.785, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.791, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.754, total=   1.2s
# [Parallel(n_jobs=1)]: Done 3240 out of 3240 | elapsed: 82.2min finished
# GridSearchCV(cv=5, estimator=SVC(random_state=12),
#              param_grid={'C': [1, 10, 30], 'class_weight': [None, 'balanced'],
#                          'coef0': [0.1, 1, 3], 'degree': [1, 3, 5],
#                          'gamma': ['auto', 0.1, 0.01],
#                          'kernel': ['rbf', 'sigmoid', 'linear', 'poly']},
#              scoring='f1_macro', verbose=3)

# %%
# train classifier
print("training...")
SVM_grid_pos.best_estimator_.fit(count_train_pos, y_train_pos)
print("complete.")
# use classifier to predict on test set
print("predicting...")
SVM_test_preds_pos = SVM_grid_pos.best_estimator_.predict(count_test_pos)
print("complete.")
# Out:
# training...
# complete.
# predicting...
# complete.

# %%
SVM_grid_pos_precision = precision_score(y_test_pos, SVM_test_preds_pos)
SVM_grid_pos_recall = recall_score(y_test_pos, SVM_test_preds_pos)
SVM_grid_pos_macro_f1_score = f1_score(y_test_pos, SVM_test_preds_pos, average='macro')

#model evaluation
print('Model evaluation metrics')
print('Precision: {:.3}'.format(SVM_grid_pos_precision))
print('Recall: {:.3}'.format(SVM_grid_pos_recall))
print('Macro F1 Score: {:.3}'.format(SVM_grid_pos_macro_f1_score))

SVM_metrics['Grid Search SVM with POS'] = {'precision': SVM_grid_pos_precision, 'recall': SVM_grid_pos_recall, 
                                           'macro_f1': SVM_grid_pos_macro_f1_score}
# Out:
# Model evaluation metrics
# Precision: 0.699
# Recall: 0.646
# Macro F1 Score: 0.805

# %%
plot_confusion_matrix(SVM_grid_pos.best_estimator_, count_test_pos, y_test_pos)

# %%
#compare parameters
results = pd.DataFrame.from_dict(SVM_metrics, orient='index')
results.to_csv(r"C:\Users\jackc\Semester2\Project\Identifying-Hate-Speech-Categories-On-Social-Media\Results\SVM_count_results.csv",
               index=True)

# %%
pd.options.display.float_format = '{:.4f}'.format
results
# Out:
#                           precision  recall  macro_f1
# Default SVM                  0.7760  0.5379    0.7886
# Grid Search SVM              0.7490  0.6570    0.8230
# Default SVM with POS         0.8042  0.4152    0.7420
# Grid Search SVM with POS     0.6992  0.6462    0.8054
