# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import svm
from sklearn.svm import LinearSVC
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, plot_confusion_matrix
import nltk

import pickle

# %%
#Load in data and split for train and test sets
df = pd.read_csv(r'C:\Users\jackc\Semester2\Project\Identifying-Hate-Speech-Categories-On-Social-Media\Data\clean_dataset.csv')
X_train, X_test, y_train, y_test = train_test_split(df['clean_text_sl'], df['Annotation'], test_size=0.25, random_state=12)
                                                       
df.head(5)
# Out:
#              id                                               text Annotation  \
# 0  5.969655e+17  I just found the *perfect* rental. Why can't m...    Neither
# 1  5.758918e+17  @wetsprocket every time they "discover" anythi...    Neither
# 2  5.952595e+17  ok time to write code bbl.\n\nmaking a new thing.    Neither
# 3  5.723449e+17                          Refined dessert! NOT #MKR    Neither
# 4  5.681320e+17  @furt1v3ly @ClarkHat One of the best things an...    Neither
#
#                                           clean_text  \
# 0  i just found the perfect rental why cant my le...
# 1   every time they discover anything its either ...
# 2    ok time to write code bbl\n\nmaking a new thing
# 3                            refined dessert not mkr
# 4    one of the best things anyone can do to impr...
#
#                                        clean_text_sl  Hate
# 0              found perfect rental cant lease right     0
# 1  every time discover anything either incorrect ...     0
# 2            ok time write code bbl making new thing     0
# 3                                refined dessert mkr     0
# 4  one best thing anyone improve understanding gr...     0

# %%
#create count matrix
counts = CountVectorizer()
count_train = counts.fit_transform(X_train)
count_test = counts.transform(X_test)

# %% [markdown]
# ## Default

# %%
SVM_default = svm.SVC(C=1.0, kernel='rbf', gamma='scale', shrinking=True,
                      class_weight=None, random_state=12)

# %%
# train classifier
print("training...")
SVM_default.fit(count_train, y_train)
print("complete.")
# use classifier to predict on test set
print("predicting...")
SVM_test_preds = SVM_default.predict(count_test)
print("complete.")
# Out:
# training...
# complete.
# predicting...
# complete.

# %%
SVM_metrics = {}
SVM_default_precision = precision_score(y_test, SVM_test_preds, average='macro')
SVM_default_recall = recall_score(y_test, SVM_test_preds, average='macro')
SVM_default_macro_f1_score = f1_score(y_test, SVM_test_preds, average='macro')

#model evaluation
print('Model evaluation metrics')
print('Precision: {:.3}'.format(SVM_default_precision))
print('Recall: {:.3}'.format(SVM_default_recall))
print('Macro F1 Score: {:.3}'.format(SVM_default_macro_f1_score))

SVM_metrics['Default SVM'] = {'precision': SVM_default_precision, 'recall': SVM_default_recall, 
                              'macro_f1': SVM_default_macro_f1_score}
# Out:
# Model evaluation metrics
# Precision: 0.741
# Recall: 0.511
# Macro F1 Score: 0.579

# %%
plot_confusion_matrix(SVM_default, count_test, y_test)

# %% [markdown]
# ## Grid

# %%
SVM_default_grid = svm.SVC(C=1.0, kernel='rbf', gamma='scale', shrinking=True,
                      class_weight=None, random_state=12)

# dictionary containing the parameters which will be used for grid search
grid_search_params={'C': [1, 10, 30],  
              'gamma': ['auto', 0.1, 0.01], 
              'kernel': ['rbf', 'sigmoid', 'linear', 'poly'],
              'coef0': [0.1, 1, 3],
              'degree': [1, 3, 5],
              'class_weight': [None, 'balanced']}

# grid search with f1 being the performance metric
SVM_grid = GridSearchCV(SVM_default_grid, grid_search_params, cv=5, scoring='f1_macro', verbose=3)
SVM_grid.fit(count_train, y_train)
# Out:
# Fitting 5 folds for each of 648 candidates, totalling 3240 fits
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.1s remaining:    0.0s
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.733, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.716, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.676, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.731, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.702, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.616, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.543, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.596, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.506, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.561, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.646, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.645, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.705, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.660, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.613, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.733, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.716, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.676, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.731, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.702, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.646, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.673, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.689, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.673, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.598, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.406, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.403, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.390, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.394, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.395, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.406, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.403, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.390, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.394, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.395, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.733, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.716, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.676, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.731, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.702, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.406, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.403, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.390, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.394, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.395, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.733, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.716, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.676, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.731, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.702, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.616, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.543, total=   1.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.596, total=   1.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.506, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.561, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.646, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.645, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.705, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.660, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.613, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.733, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.716, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.676, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.731, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.702, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.490, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.437, total=   2.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.392, total=   2.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.405, total=   2.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.401, total=   2.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.406, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.403, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.390, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.394, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.395, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.406, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.403, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.390, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.394, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.395, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.733, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.716, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.676, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.731, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.702, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.733, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.716, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.676, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.731, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.702, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.616, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.543, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.596, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.506, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.561, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.646, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.645, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.705, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.660, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.613, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.733, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.716, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.676, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.731, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.702, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.346, total=   3.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.288, total=   2.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.253, total=   3.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.276, total=   2.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.286, total=   3.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.406, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.403, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.390, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.394, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.395, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.406, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.403, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.390, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.394, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.395, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.733, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.716, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.676, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.731, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.702, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.733, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.716, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.676, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.731, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.702, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.616, total=   1.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.543, total=   1.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.596, total=   1.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.506, total=   1.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.561, total=   1.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.442, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.407, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.516, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.465, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.467, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.733, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.716, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.676, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.731, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.702, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.646, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.673, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.689, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.673, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.598, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.406, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.403, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.390, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.394, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.395, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.235, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.236, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.733, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.716, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.676, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.731, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.702, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.406, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.403, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.390, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.394, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.395, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.733, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.716, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.676, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.731, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.702, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.616, total=   1.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.543, total=   1.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.596, total=   1.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.506, total=   1.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.561, total=   1.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid, score=0.442, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid, score=0.407, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# ...
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.743, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.685, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.778, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.630, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.701, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.795, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.681, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.769, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.790, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.672, total=   3.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.742, total=   3.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.664, total=   3.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.721, total=   3.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.766, total=   3.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.700, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.759, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.676, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.763, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.677, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.696, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.761, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.678, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.772, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.698, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.673, total=   2.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.732, total=   2.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.674, total=   2.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.750, total=   2.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.770, total=   2.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   3.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.006, total=   3.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.059, total=   3.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.059, total=   3.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.059, total=   3.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.700, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.759, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.676, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.763, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.677, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.687, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.755, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.668, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.769, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.752, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.688, total=   1.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.665, total=   1.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.631, total=   1.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.645, total=   1.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.619, total=   1.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.628, total=   1.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.704, total=   1.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.640, total=   1.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.694, total=   1.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.698, total=   1.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.700, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.759, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.676, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.763, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.677, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.712, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.751, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.683, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.753, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.632, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.701, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.795, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.681, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.769, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.790, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.672, total=   3.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.742, total=   3.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.664, total=   3.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.721, total=   3.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.766, total=   3.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.700, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.759, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.676, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.763, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.677, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.702, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.757, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.677, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.773, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.610, total=   0.6s
# [Parallel(n_jobs=1)]: Done 3240 out of 3240 | elapsed: 71.8min finished
# GridSearchCV(cv=5, estimator=SVC(random_state=12),
#              param_grid={'C': [1, 10, 30], 'class_weight': [None, 'balanced'],
#                          'coef0': [0.1, 1, 3], 'degree': [1, 3, 5],
#                          'gamma': ['auto', 0.1, 0.01],
#                          'kernel': ['rbf', 'sigmoid', 'linear', 'poly']},
#              scoring='f1_macro', verbose=3)

# %%
# train classifier
print("training...")
SVM_grid.best_estimator_.fit(count_train, y_train)
print("complete.")
# use classifier to predict on test set
print("predicting...")
SVM_test_preds = SVM_grid.best_estimator_.predict(count_test)
print("complete.")
# Out:
# training...
# complete.
# predicting...
# complete.

# %%
SVM_grid_precision = precision_score(y_test, SVM_test_preds, average='macro') 
SVM_grid_recall = recall_score(y_test, SVM_test_preds, average='macro')
SVM_grid_macro_f1_score = f1_score(y_test, SVM_test_preds, average='macro')

#model evaluation
print('Model evaluation metrics')
print('Precision: {:.3}'.format(SVM_grid_precision))
print('Recall: {:.3}'.format(SVM_grid_recall))
print('Macro F1 Score: {:.3}'.format(SVM_grid_macro_f1_score))

SVM_metrics['Grid Search SVM'] = {'precision': SVM_grid_precision, 'recall': SVM_grid_recall, 
                                  'macro_f1': SVM_grid_macro_f1_score}
# Out:
# Model evaluation metrics
# Precision: 0.666
# Recall: 0.711
# Macro F1 Score: 0.674

# %%
plot_confusion_matrix(SVM_grid.best_estimator_, count_test, y_test)

# %%
#compare parameters
results = pd.DataFrame.from_dict(SVM_metrics, orient='index')
results.to_csv(r"C:\Users\jackc\Semester2\Project\Identifying-Hate-Speech-Categories-On-Social-Media\Results\SVM_count_results_multi.csv",
               index=True)
results
# Out:
#                  precision   recall  macro_f1
# Default SVM       0.741354  0.51123  0.578771
# Grid Search SVM   0.666009  0.71113  0.673872

# %% [markdown]
# ## Default SVM - no SL

# %%
#Load in data and split for train and test sets
df = pd.read_csv(r'C:\Users\jackc\Semester2\Project\Identifying-Hate-Speech-Categories-On-Social-Media\Data\clean_dataset.csv')
X_train, X_test, y_train, y_test = train_test_split(df['clean_text'], df['Annotation'], test_size=0.25, random_state=12)
                                                       
df.head(5)
# Out:
#              id                                               text Annotation  \
# 0  5.969655e+17  I just found the *perfect* rental. Why can't m...    Neither
# 1  5.758918e+17  @wetsprocket every time they "discover" anythi...    Neither
# 2  5.952595e+17  ok time to write code bbl.\n\nmaking a new thing.    Neither
# 3  5.723449e+17                          Refined dessert! NOT #MKR    Neither
# 4  5.681320e+17  @furt1v3ly @ClarkHat One of the best things an...    Neither
#
#                                           clean_text  \
# 0  i just found the perfect rental why cant my le...
# 1   every time they discover anything its either ...
# 2    ok time to write code bbl\n\nmaking a new thing
# 3                            refined dessert not mkr
# 4    one of the best things anyone can do to impr...
#
#                                        clean_text_sl  Hate
# 0              found perfect rental cant lease right     0
# 1  every time discover anything either incorrect ...     0
# 2            ok time write code bbl making new thing     0
# 3                                refined dessert mkr     0
# 4  one best thing anyone improve understanding gr...     0

# %%
#create count matrix
counts = CountVectorizer()
count_train = counts.fit_transform(X_train)
count_test = counts.transform(X_test)

# %%
SVM_default = svm.SVC(C=1.0, kernel='rbf', gamma='scale', shrinking=True,
                      class_weight=None, random_state=12)

# %%
# train classifier
print("training...")
SVM_default.fit(count_train, y_train)
print("complete.")
# use classifier to predict on test set
print("predicting...")
SVM_test_preds = SVM_default.predict(count_test)
print("complete.")
# Out:
# training...
# complete.
# predicting...
# complete.

# %%
SVM_default_precision = precision_score(y_test, SVM_test_preds, average='macro')
SVM_default_recall = recall_score(y_test, SVM_test_preds, average='macro')
SVM_default_macro_f1_score = f1_score(y_test, SVM_test_preds, average='macro')

#model evaluation
print('Model evaluation metrics')
print('Precision: {:.3}'.format(SVM_default_precision))
print('Recall: {:.3}'.format(SVM_default_recall))
print('Macro F1 Score: {:.3}'.format(SVM_default_macro_f1_score))

SVM_metrics['Default SVM - no SL'] = {'precision': SVM_default_precision, 'recall': SVM_default_recall, 
                              'macro_f1': SVM_default_macro_f1_score}
# Out:
# Model evaluation metrics
# Precision: 0.865
# Recall: 0.45
# Macro F1 Score: 0.517

# %%
plot_confusion_matrix(SVM_default, count_test, y_test)

# %% [markdown]
# ## Grid SVM - no SL

# %%
SVM_default_grid = svm.SVC(C=1.0, kernel='rbf', gamma='scale', shrinking=True,
                      class_weight=None, random_state=12)

# dictionary containing the parameters which will be used for grid search
grid_search_params={'C': [1, 10, 30],  
              'gamma': ['auto', 0.1, 0.01], 
              'kernel': ['rbf', 'sigmoid', 'linear', 'poly'],
              'coef0': [0.1, 1, 3],
              'degree': [1, 3, 5],
              'class_weight': [None, 'balanced']}

# grid search with f1 being the performance metric
SVM_grid = GridSearchCV(SVM_default_grid, grid_search_params, cv=5, scoring='f1_macro', verbose=3)
SVM_grid.fit(count_train, y_train)
# Out:
# Fitting 5 folds for each of 648 candidates, totalling 3240 fits
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.6s remaining:    0.0s
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.738, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.692, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.650, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.678, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.427, total=   3.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.411, total=   3.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.369, total=   3.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.382, total=   3.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.415, total=   3.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.604, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.478, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.564, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.529, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.509, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.738, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.692, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.678, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.647, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.601, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.678, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.551, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.637, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.407, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.403, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.390, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.394, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.395, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.406, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.403, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.390, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.394, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.395, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.738, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.692, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.678, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.406, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.403, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.390, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.394, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.395, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.738, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.692, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.678, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.427, total=   3.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.411, total=   3.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.369, total=   3.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.382, total=   3.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.415, total=   3.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.604, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.478, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.564, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.529, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.509, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.738, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.692, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.650, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.678, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.492, total=   3.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.431, total=   3.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.350, total=   3.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.406, total=   3.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.379, total=   3.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.407, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.403, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.390, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.394, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.395, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.406, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.403, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.390, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.394, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.395, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.738, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.692, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.678, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   1.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.738, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.692, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.650, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.678, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.427, total=   3.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.411, total=   3.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.369, total=   3.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.382, total=   3.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.415, total=   3.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.604, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.478, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.564, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.529, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.509, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.738, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.692, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.678, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.396, total=   4.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.275, total=   4.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.269, total=   5.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.285, total=   4.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.298, total=   4.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.407, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.403, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.390, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.394, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.395, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.406, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.403, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.390, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.394, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.395, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.738, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.692, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.650, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.678, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   1.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   1.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.738, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.692, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.650, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.678, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.427, total=   3.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.411, total=   3.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.369, total=   3.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.382, total=   3.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.415, total=   3.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.382, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.381, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.383, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.375, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.370, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.738, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.692, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.678, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.647, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.601, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.678, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.551, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.637, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.407, total=   1.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.403, total=   1.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.390, total=   1.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.394, total=   1.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.395, total=   1.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.235, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.236, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.228, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.228, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.228, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.738, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.692, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.678, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.406, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.403, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.390, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.394, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.395, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.738, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.692, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.650, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.678, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.427, total=   3.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.411, total=   3.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.369, total=   3.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.382, total=   3.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.415, total=   3.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid, score=0.382, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid, score=0.381, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# ...
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.697, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.664, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.642, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.599, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.732, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.740, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.654, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.621, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.755, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.722, total=   4.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.740, total=   4.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.598, total=   4.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.612, total=   4.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.688, total=   4.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.737, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.738, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.644, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.678, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.631, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.734, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.733, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.650, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.693, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.678, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.710, total=   3.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.717, total=   3.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.666, total=   2.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.653, total=   2.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.754, total=   3.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   5.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.006, total=   5.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.059, total=   5.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.059, total=   5.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.059, total=   5.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.737, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.738, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.644, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.678, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.631, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.740, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.752, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.660, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.692, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.691, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.592, total=   3.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.557, total=   3.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.508, total=   3.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.512, total=   3.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.484, total=   3.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.523, total=   2.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.528, total=   2.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.507, total=   2.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.524, total=   2.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.515, total=   2.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.737, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.738, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.644, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.678, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.631, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.699, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.656, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.641, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.610, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.607, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.732, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.740, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.654, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.621, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.755, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.722, total=   4.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.740, total=   4.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.598, total=   4.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.612, total=   4.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.688, total=   4.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.737, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.738, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.644, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.678, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.631, total=   1.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.745, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.727, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.662, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.670, total=   1.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.584, total=   1.1s
# [Parallel(n_jobs=1)]: Done 3240 out of 3240 | elapsed: 101.6min finished
# GridSearchCV(cv=5, estimator=SVC(random_state=12),
#              param_grid={'C': [1, 10, 30], 'class_weight': [None, 'balanced'],
#                          'coef0': [0.1, 1, 3], 'degree': [1, 3, 5],
#                          'gamma': ['auto', 0.1, 0.01],
#                          'kernel': ['rbf', 'sigmoid', 'linear', 'poly']},
#              scoring='f1_macro', verbose=3)

# %%
# train classifier
print("training...")
SVM_grid.best_estimator_.fit(count_train, y_train)
print("complete.")
# use classifier to predict on test set
print("predicting...")
SVM_test_preds = SVM_grid.best_estimator_.predict(count_test)
print("complete.")
# Out:
# training...
# complete.
# predicting...
# complete.

# %%
SVM_grid_precision = precision_score(y_test, SVM_test_preds, average='macro') 
SVM_grid_recall = recall_score(y_test, SVM_test_preds, average='macro')
SVM_grid_macro_f1_score = f1_score(y_test, SVM_test_preds, average='macro')

#model evaluation
print('Model evaluation metrics')
print('Precision: {:.3}'.format(SVM_grid_precision))
print('Recall: {:.3}'.format(SVM_grid_recall))
print('Macro F1 Score: {:.3}'.format(SVM_grid_macro_f1_score))

SVM_metrics['Grid Search SVM - no SL'] = {'precision': SVM_grid_precision, 'recall': SVM_grid_recall, 
                                  'macro_f1': SVM_grid_macro_f1_score}
# Out:
# Model evaluation metrics
# Precision: 0.71
# Recall: 0.666
# Macro F1 Score: 0.65

# %%
plot_confusion_matrix(SVM_grid.best_estimator_, count_test, y_test)

# %%
#compare parameters
results = pd.DataFrame.from_dict(SVM_metrics, orient='index')
results.to_csv(r"C:\Users\jackc\Semester2\Project\Identifying-Hate-Speech-Categories-On-Social-Media\Results\SVM_count_results_multi.csv",
               index=True)
results
# Out:
#                          precision    recall  macro_f1
# Default SVM               0.741354  0.511230  0.578771
# Grid Search SVM           0.666009  0.711130  0.673872
# Default SVM - no SL       0.864760  0.450275  0.516699
# Grid Search SVM - no SL   0.709709  0.666249  0.650090
